# %% [markdown]
# # 20190121 TTT Day 1 Couse

# %% [markdown]
# ### 1. Microsoft Professional Program 소개 (함성원 과장)

# %% [markdown]
# ### 2. Microsoft Professional Program 접속
# [https://academy.microsoft.com/en-us/professional-program/](https://academy.microsoft.com/en-us/professional-program/)<br>
# [https://www.datamine.co.kr](https://www.datamine.co.kr)

# %% [markdown]
# ### 3. Azure Account 확인 및 파일 준비
# #### Azure Account
# 1. If you already have a Microsoft account that has not already been used to sign up for a free Azure trial subscription, you’re ready to get started. If not, don’t worry, just create a new Microsoft account at https://signup.live.com.
#
# 2. After you’ve created a Microsoft account, go https://aka.ms/edx-dat263x-az and follow the instructions to sign up for a free 30-day trial subscription to Microsoft Azure.
# Note: When activating a 30-day trial Azure subscription, you will need to provide valid credit card details –your credit card won’t be charged for any Azure services you use during the trial period, and the account is automatically deactivated at the end of the trial period unless you
#  explicitly decide to keep it active. A small transaction, which is refunded, may be used to validate the credit card.
#
# #### Install the Lab Files
# Install the Lab Files To complete the labs in this course, you will need to download and extract the lab files from the course GitHub repository. 1. Download the lab files zip archive from https://aka.ms/edx-dat263x-labfiles. 2. Extract the lab files to a folder on your computer.
#
# #### Optional: Install the Anaconda Python Distribution
# You can complete the labs using only a web browser and the lab files. However, some of the techniques demonstrated in this course require a local installation of Python and Jupyter Notebooks. The notebooks used in the demonstration videos are provided at https://aka.ms/edx-dat263x-demos. If you wish to explore the demo code, you’ll need to install Jupyter and the Python 3.6 kernel. For details of how to install Jupyter and Python, visit the Jupyter site at https://jupyter.org.

# %% [markdown]
# ### 4. Jupyter Notebook & Azure Notebook
# Jupyter Notebook은 Python 개발에 거의 필수적으로 사용되고 있다. 원래 IPython으로 진행되던 프로젝트에서 Notebook으로 발전하고 있으며 Open Source 프로젝트로 지금은 Python 이외에도 R, Node.js, F#등 다양한 언어들을 지원하고 있다.
#
# 공식 사이트 https://jupyter.org/ <br>
# 수식 샘플 https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Typesetting%20Equations.html <br>
# 설치 방법 외 기타 http://goodtogreate.tistory.com/entry/IPython-Notebook-%EC%84%A4%EC%B9%98%EB%B0%A9%EB%B2%95 <br>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('zun2aRYB2mY',width=600,height=480)

# %% [markdown]
# ### 5. Welcome to Microsoft's Introduction to Artificial Intelligence(AI)

# %% [markdown]
# [https://www.datamine.co.kr/courses/course-v1:Microsoft+DAT263x+2018_T2/info](https://www.datamine.co.kr/courses/course-v1:Microsoft+DAT263x+2018_T2/info)

# %% [markdown]
# ### 5-1 Machine Learning

# %% [markdown]
# ##### Machine Learning Fundamentals current section

# %%
YouTubeVideo('a_8ALtM5rnQ',width=640, height=480)

# %%
YouTubeVideo('1O0_u9WRo-0', width=640, height=480)

# %% [markdown]
# ##### Azure Machine Learning Studio

# %% [markdown]
# 1. Calories와 Exercise 두 개의 CSV 파일을 업로드 한다.
# 2. Experiments를 추가하고 이름을 Calories로 수정한다.
# 3. exercise.csv 파일을 Visualize 해보고 Heart_Rate 항목의 데이터와 히스토그램을 확인한다.
# 4. Join Data를 사용해서 exercise와 calorise를 Join한다.
# 5. Join key columns for L과 R모두 Launch column selector에서 User_ID column을 선택한다.
# 6. Join key columns for R에서는 with Rules를 선택하고 No Columns를 선택한 다음 User_ID 컬럼을 선택한다.
# 7. Match case 항목에 체크를 확인한다.
# 8. Join type을 Left Outer Join을 선택한다.
# 9. 오른쪽 키 열을 유지하지 않기 위해서 Keep right key column 항목의 체크를 제외한다.
# 10. 당장 Visualize를 사용할 수 없기 때문에 Run을 선택한다.
# 11. 데이터를 확인해 보면 Data가 잘 Join된 것을 확인 할 수 있다.
# 12. Convert to CSV 모듈을 추가하고 연결한다.
# 13. Convert to CSV 모듈에서 Jupyter Notebook에서 열어본다. 이때 언어는 Python을 선택한다.
# 14. frame을 확인한 다음 아래와 같은 코드를 삽입한다.
#
# ```python
# %matplotlib inline
#
# import seaborn as sns
# num_cols = ['Age','Height','Weight','Duration','Heart_Rate','Body_Temp','Calories']
# sns.pairplot(frame[num_cols], size=2)
# ```

# %% [markdown]
# 1. Edit Metadata 모듈을 추가합니다.
# 2. Edit Metadata에서 Gender 컬럼을 선택하고 make category를 선택합니다.
# 3. Apply Math Operation 항목을 선택합니다. (수학연산 모듈) - Output mode를 append로 설정한다.
#    이 모듈에서는 지속시간과 심박수를 제곱해 줍니다. (피쳐 engineering을 위해서)
# 4. Apply Math Operation을 추가합ㄴ디ㅏ. Basic math function을 Ln을 선택합니다 (자연로그) 그리고 컬럼은 Calories를 선택합니다.
# 5. Nomalize Data를 추가합니다.

# %% [markdown]
# https://github.com/Azure-Readiness/hol-azure-machine-learning/blob/master/006-lab-model-evaluation.md

# %% [markdown]
# ##### Lab
# ### 5-2 Language and Communication
# #### Getting Started with Text Processing
# #### Introduction to Natural Language Processing
# #### Language Understanding Intelligent Service
# #### Lab
# ### 5-3 Computer Vision
# #### Getting Started with Image Processing
# #### Working with Images and Video
# #### Lab
# ### 5-4 Conversation as a Platform
# #### Introduction to Bots
# #### Building Intelligent Bots
# #### Lab
# ### 5-5 Learning More
# #### Beyond the Basics
# #### Where Do I Go From Here?
# ### 5-6 Get Microsoft Course Completion Certificate
